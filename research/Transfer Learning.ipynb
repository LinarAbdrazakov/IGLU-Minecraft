# %%
# !pip3 uninstall -y iglu && pip3 install git+https://github.com/iglu-contest/iglu.git
# Out:
# Found existing installation: iglu 0.2.2
# Uninstalling iglu-0.2.2:
#   Successfully uninstalled iglu-0.2.2
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...
#   Cloning https://github.com/iglu-contest/iglu.git to /tmp/pip-req-build-4u_6ngk2
#   Running command git clone -q https://github.com/iglu-contest/iglu.git /tmp/pip-req-build-4u_6ngk2
# ...
#      |████████████████████████████████| 356 kB 1.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.5 MB 17.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 176 kB 48.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 85 kB 11.4 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 45 kB 11.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 146 kB 51.7 MB/s eta 0:00:01
# ...

# %%
# !pip3 uninstall -y minerl-patched && pip3 install git+https://github.com/iglu-contest/minerl.git
# Out:
# Found existing installation: minerl-patched 0.1.0
# Uninstalling minerl-patched-0.1.0:
#   Successfully uninstalled minerl-patched-0.1.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...
#   Cloning https://github.com/iglu-contest/minerl.git to /tmp/pip-req-build-xjwksjfl
#   Running command git clone -q https://github.com/iglu-contest/minerl.git /tmp/pip-req-build-xjwksjfl
# ...
#   Created wheel for minerl-patched: filename=minerl_patched-0.1.0-cp37-cp37m-linux_x86_64.whl size=660183315 sha256=db4f9f8323549109eb5b03b6bae90c996fb4a7ee636388bc0f8a59e7e5cd0b37
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hzlsd984/wheels/f8/53/52/5208e35814cc1cb84dedda25722b5e7f6e13d08bcc69c9a72c
# Successfully built minerl-patched
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# Data Loading

#import iglu
#data = iglu.data.download(directory='/IGLU-Minecraft/demonstrations')

# %%
import iglu
from tqdm import tqdm

data = iglu.data.make(data_dir='/IGLU-Minecraft/demonstrations/', force_download=True)

#for current_state, action, reward, next_state, done, info \
#    in tqdm(data.batch_iter(num_epochs=2, seq_len=32, batch_size=10, include_metadata=True)):
#    pass
# Out:
# /root/miniconda/envs/py37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /root/miniconda/envs/py37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Provided data directory does not exist:  /IGLU-Minecraft/demonstrations/
# downloading dataset: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:08<00:00, 248.61s/it]
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ...

# %%
for current_state, action, reward, next_state, done, info \
    in tqdm(data.batch_iter(num_epochs=2, seq_len=32, batch_size=10, include_metadata=True)):
    pass
# Out:
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 65/65 [00:00<00:00, 6099.92it/s]
# 885it [00:46, 16.43it/s] Exception in thread QueueManagerThread:
# Traceback (most recent call last):
#   File "/root/miniconda/envs/py37/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/root/miniconda/envs/py37/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda/envs/py37/lib/python3.7/concurrent/futures/process.py", line 368, in _queue_management_worker
#     thread_wakeup.clear()
#   File "/root/miniconda/envs/py37/lib/python3.7/concurrent/futures/process.py", line 93, in clear
#     self._reader.recv_bytes()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# ...
